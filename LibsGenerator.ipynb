# %%
# Mad Libs Generator

noun = "dog"
verb = "run"
adjective = "happy"
place = "park"

# Story template using f-string
story = f"Today I saw a {adjective} {noun} {verb} in the {place}. " \
        f"It made me laugh so much that I decided to {verb} too!"

# Display the story
story
# Out:
# 'Today I saw a happy dog run in the park. It made me laugh so much that I decided to run too!'
